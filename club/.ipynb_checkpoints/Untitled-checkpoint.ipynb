# %%
from member import membertypes as mt
class club:
    def __init__(self, playerList=None, staffList=None):
        self.members = {'players':[], 'staff':[]}
        if playerList!=None:
            for player in playerList:
                self.addPlayer(player[0], player[1], player[2], player[3], player[4], player[5])
        self.fans = {'domestic':[], 'international':[]}
        if staffList!=None:
            for staff in staffList:
                self.addStaff(staff[0], staff[1], staff[2], staff[3], staff[4])
        self.fans = {'domestic':[], 'international':[]}
    
    def addPlayer(self, name, nationality, salary, yearsWClub, position, jersey):
        newPlayer = mt.player(name, nationality, salary, yearsWClub, position, jersey)
        self.members['players'].append(newPlayer)
    
    def addStaff(self, name, nationality, salary, yearsWClub, title):
        newStaff = mt.staff(name, nationality, salary, yearsWClub, title)
        self.members['staff'].append(newStaff)
        
    def displayPlayers(self):
        for player in self.members['players']:
            player.display()
            print("\n")
            
    def displayStaff(self):
        for staff in self.members['staff']:
            staff.display()
            print("\n")
    
    def displayMembers(self):
        self.displayStaff()
        self.displayPlayers()

# %%
"""madrid.addPlayer('Sergio Ramos', 'Spain', 15000000, 14, 'Right Back', 15)
madrid.addPlayer('Other Player', 'Spanish', 2, 3, 'Striker', 4)
madrid.displayPlayers()
madrid.addStaff('Zinedine Zidane', 'France', 5500000, 9, 'Skipper')
madrid.addStaff('Other Staff', 'Spain', 23, 4, 'Lead Napper')
madrid.displayStaff()
print('###################################################')
madrid.displayMembers()"""
plist = [['Sergio Ramos', 'Spain', 15000000, 14, 'Right Back', 15],['Other Player', 'Spanish', 2, 3, 'Striker', 4]]
slist = [['Zinedine Zidane', 'France', 5500000, 9, 'Skipper'],['Other Staff', 'Spain', 23, 4, 'Lead Napper']]
madrid = club(plist, slist)
madrid.displayPlayers()
print('###################################################')
madrid.displayStaff()
print('###################################################')
madrid.displayMembers()
# Out:
#            Name: Sergio Ramos
#     Nationality: Spain
# Years With Club: 14
#        Position: Right Back
#   Jersey Number: 15
#
#
#            Name: Other Player
#     Nationality: Spanish
# Years With Club: 3
#        Position: Striker
#   Jersey Number: 4
#
#
# ###################################################
#            Name: Zinedine Zidane
#     Nationality: France
# Years With Club: 9
#       Job Title: Skipper
#
#
#            Name: Other Staff
#     Nationality: Spain
# Years With Club: 4
#       Job Title: Lead Napper
#
#
# ###################################################
#            Name: Zinedine Zidane
#     Nationality: France
# Years With Club: 9
#       Job Title: Skipper
#
#
#            Name: Other Staff
#     Nationality: Spain
# Years With Club: 4
#       Job Title: Lead Napper
#
#
#            Name: Sergio Ramos
#     Nationality: Spain
# Years With Club: 14
#        Position: Right Back
#   Jersey Number: 15
#
#
#            Name: Other Player
#     Nationality: Spanish
# Years With Club: 3
#        Position: Striker
#   Jersey Number: 4
